# %%
# data manipulation libraries
import pandas as pd
import numpy as np

# visualisation libraries
import seaborn as sns
import matplotlib.pyplot as plt

# machine learning libraries
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report

import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.identify_missing_data import identify_missing_data
# Out:
#   File "C:\Users\guilh\AppData\Local\Temp\ipykernel_3740\112557145.py", line 21
#     from src.identify-missing-data import identify_missing_data
#                      ^
# SyntaxError: invalid syntax

# %%
housing_data = pd.read_pickle("../data/housing_data.pkl")
housing_data
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave  None      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave  None      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave  None      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave  None      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave  None      Reg
#
#      LandContour Utilities  ... 3SsnPorch ScreenPorch PoolArea  PoolQC  Fence  \
# 0            Lvl    AllPub  ...       0.0         0.0      0.0    None   None
# 1            Lvl    AllPub  ...       0.0         0.0      0.0    None   None
# 2            Lvl    AllPub  ...       0.0         0.0      0.0    None   None
# 3            Lvl    AllPub  ...       0.0         0.0      0.0    None   None
# 4            Lvl    AllPub  ...       0.0         0.0      0.0    None   None
# ...          ...       ...  ...       ...         ...      ...     ...    ...
# 1455         Lvl    AllPub  ...       0.0         0.0      0.0    None   None
# 1456         Lvl    AllPub  ...       0.0         0.0      0.0    None  MnPrv
# 1457         Lvl    AllPub  ...       0.0         0.0      0.0    None  GdPrv
# 1458         Lvl    AllPub  ...       0.0         0.0      0.0    None   None
# 1459         Lvl    AllPub  ...       0.0         0.0      0.0    None   None
#
#       MiscFeature  MiscVal MoSold  YrSold    target
# 0            None      0.0    2.0  2008.0  208500.0
# 1            None      0.0    5.0  2007.0  181500.0
# 2            None      0.0    9.0  2008.0  223500.0
# 3            None      0.0    2.0  2006.0  140000.0
# 4            None      0.0   12.0  2008.0  250000.0
# ...           ...      ...    ...     ...       ...
# 1455         None      0.0    8.0  2007.0  175000.0
# 1456         None      0.0    2.0  2010.0  210000.0
# 1457         Shed   2500.0    5.0  2010.0  266500.0
# 1458         None      0.0    4.0  2010.0  142125.0
# 1459         None      0.0    6.0  2008.0  147500.0
#
# [1460 rows x 61 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
housing_data.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1  2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2  3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3  4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4  5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
#
#   LandContour Utilities LotConfig LandSlope BldgType  OverallQual  \
# 0         Lvl    AllPub    Inside       Gtl     1Fam          7.0
# 1         Lvl    AllPub       FR2       Gtl     1Fam          6.0
# 2         Lvl    AllPub    Inside       Gtl     1Fam          7.0
# 3         Lvl    AllPub    Corner       Gtl     1Fam          7.0
# 4         Lvl    AllPub       FR2       Gtl     1Fam          8.0
#
#    OverallCond  YearBuilt  YearRemodAdd MasVnrType  MasVnrArea ExterQual  \
# 0          5.0     2003.0        2003.0    BrkFace       196.0        Gd
# 1          8.0     1976.0        1976.0       None         0.0        TA
# 2          5.0     2001.0        2002.0    BrkFace       162.0        Gd
# 3          5.0     1915.0        1970.0       None         0.0        TA
# 4          5.0     2000.0        2000.0    BrkFace       350.0        Gd
#
#   ExterCond BsmtQual BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0        TA       Gd       TA           No       706.0         0.0      150.0
# 1        TA       Gd       TA           Gd       978.0         0.0      284.0
# 2        TA       Gd       TA           Mn       486.0         0.0      434.0
# 3        TA       TA       Gd           No       216.0         0.0      540.0
# 4        TA       Gd       TA           Av       655.0         0.0      490.0
#
#    TotalBsmtSF HeatingQC CentralAir  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0        856.0        Ex          Y     856.0     854.0           0.0
# 1       1262.0        Ex          Y    1262.0       0.0           0.0
# 2        920.0        Ex          Y     920.0     866.0           0.0
# 3        756.0        Gd          Y     961.0     756.0           0.0
# 4       1145.0        Ex          Y    1145.0    1053.0           0.0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0     1710.0           1.0           0.0       2.0       1.0           3.0
# 1     1262.0           0.0           1.0       2.0       0.0           3.0
# 2     1786.0           1.0           0.0       2.0       1.0           3.0
# 3     1717.0           1.0           0.0       1.0       0.0           3.0
# 4     2198.0           1.0           0.0       2.0       1.0           4.0
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# 0           1.0          Gd           8.0         0.0       2003.0
# 1           1.0          TA           6.0         1.0       1976.0
# 2           1.0          Gd           6.0         1.0       2001.0
# 3           1.0          Gd           7.0         1.0       1998.0
# 4           1.0          Gd           9.0         1.0       2000.0
#
#   GarageFinish  GarageCars  GarageArea PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0          RFn         2.0       548.0          Y         0.0         61.0
# 1          RFn         2.0       460.0          Y       298.0          0.0
# 2          RFn         2.0       608.0          Y         0.0         42.0
# 3          Unf         3.0       642.0          Y         0.0         35.0
# 4          RFn         3.0       836.0          Y       192.0         84.0
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 0            0.0        0.0          0.0       0.0   None  None        None
# 1            0.0        0.0          0.0       0.0   None  None        None
# 2            0.0        0.0          0.0       0.0   None  None        None
# 3          272.0        0.0          0.0       0.0   None  None        None
# 4            0.0        0.0          0.0       0.0   None  None        None
#
#    MiscVal  MoSold  YrSold    target
# 0      0.0     2.0  2008.0  208500.0
# 1      0.0     5.0  2007.0  181500.0
# 2      0.0     9.0  2008.0  223500.0
# 3      0.0     2.0  2006.0  140000.0
# 4      0.0    12.0  2008.0  250000.0

# %%
plt.rcParams["figure.figsize"] = (20,20)
housing_data.hist();
